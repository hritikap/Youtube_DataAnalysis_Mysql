# %% [markdown]
# ## Youtube Data Analysis
# ![channels4_profile-3.jpg](attachment:channels4_profile-3.jpg)

# %% [markdown]
# ### In this two sql tables videos_stats and comment_data from the database named youtubeanalysis are loaded and different analysis is performed using these tables.

# %%
# %load_ext sql

# %%
import MySQLdb as sql

# %% [markdown]
# ### First lets connect to the database and perform sql queries to manipulate the table datas

# %%
# %sql mysql+mysqldb://root:root@localhost/youtubeanalysis
# Out:
# 'Connected: root@youtubeanalysis'

# %%
# %sql Select * from videos_stats limit 20;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 20 rows affected.
# [('Apple Pay Is Killing the Physical Wallet After Only Eight Years | Tech News Briefing Podcast | WSJ', 'wAZZ-UWGVHI', datetime.date(2022, 8, 23), 'tech', 3407.0, 672.0, 135612.0),
#  ('The most EXPENSIVE thing I own.', 'b3x28s61q3c', datetime.date(2022, 8, 24), 'tech', 76779.0, 4306.0, 1758060.0),
#  ('My New House Gaming Setup is SICK!', '4mgePWWCAmA', datetime.date(2022, 8, 23), 'tech', 63825.0, 3338.0, 1564010.0),
#  ('Petrol Vs Liquid Nitrogen | Freezing Experiment | പെട്രോളിനെ ഐസ് ആകാൻ പറ്റുമോ | M4 Tech |', 'kXiYSI7H2b0', datetime.date(2022, 8, 23), 'tech', 71566.0, 1426.0, 922918.0),
#  ('Best Back to School Tech 2022!', 'ErMwWXQxHp0', datetime.date(2022, 8, 8), 'tech', 96513.0, 5155.0, 1855640.0),
#  ('Brewmaster Answers Beer Questions From Twitter | Tech Support | WIRED', '18fwz9Itbvo', datetime.date(2021, 11, 5), 'tech', 33570.0, 1643.0, 943119.0),
# ...

# %% [markdown]
# ### What are the top 15 most liked and commented videos?

# %%
# %%sql
# select Title,Video_id,keyword,likes from videos_stats order by likes desc limit 10;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 10 rows affected.
# [('El Chombo - Dame Tu Cosita feat. Cutty Ranks (Official Video) [Ultra Music]', 'FzG4uDgje3M', 'google', 16445600.0),
#  ('$456,000 Squid Game In Real Life!', '0e3GPea1Tyg', 'mrbeast', 14259000.0),
#  ('Martin Garrix - Animals (Official Video)', 'gCYcHz2k5x0', 'animals', 11025200.0),
#  ('Powfu - death bed (coffee for your head) (Official Video) ft. beabadoobee', 'jJPMnTXl63E', 'bed', 7786060.0),
#  ('The Weeknd - Save Your Tears (Official Music Video)', 'XXYlFuWEuKI', 'music', 6823110.0),
#  ('Glass Animals - Heat Waves (Official Video)', 'mRD0-GxqHVo', 'animals', 6177590.0),
#  ('I Spent 50 Hours Buried Alive', '9bqk6ZUsKyA', 'mrbeast', 6055500.0),
#  ('Maroon 5 - Animals (Official Music Video)', 'qpgTC9MDx1o', 'animals', 5743880.0),
#  ('history of the entire world, i guess', 'xuCn8ux2gbs', 'history', 5471650.0),
#  ('One Direction - History (Official Video)', 'yjmp8CoZBIo', 'history', 5400590.0)]

# %%
# %%sql
# select Title,Video_id,keyword,comments from videos_stats order by comments desc limit 10;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 10 rows affected.
# [('El Chombo - Dame Tu Cosita feat. Cutty Ranks (Official Video) [Ultra Music]', 'FzG4uDgje3M', 'google', 732818.0),
#  ('I Opened A Restaurant That Pays You To Eat At It', 'dg2Ag3e8W-Q', 'mrbeast', 728774.0),
#  ('$456,000 Squid Game In Real Life!', '0e3GPea1Tyg', 'mrbeast', 611757.0),
#  ('One Direction - History (Official Video)', 'yjmp8CoZBIo', 'history', 434688.0),
#  ('history of the entire world, i guess', 'xuCn8ux2gbs', 'history', 395657.0),
#  ('Martin Garrix - Animals (Official Video)', 'gCYcHz2k5x0', 'animals', 335455.0),
#  ('PIKOTARO - PPAP (Pen Pineapple Apple Pen) (Long Version) [Official Video]', 'Ct6BUPvE2sM', 'apple', 294428.0),
#  ('The Weeknd - Save Your Tears (Official Music Video)', 'XXYlFuWEuKI', 'music', 270948.0),
#  ('I Spent 50 Hours Buried Alive', '9bqk6ZUsKyA', 'mrbeast', 239172.0),
#  ('I Gave My 100,000,000th Subscriber An Island', '2isYuQZMbdU', 'mrbeast', 224423.0)]

# %% [markdown]
# ### How many total views and like does each category have ?

# %%
# %%sql
# select keyword as category, sum(views) as total_views,sum(likes)as total_likes from videos_stats group by keyword;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 41 rows affected.
# [('tech', 89624908.0, 2828217.0),
#  ('news', 8745974.0, 110103.0),
#  ('gaming', 20746649.0, 1004444.0),
#  ('sports', 315444560.0, 3568351.0),
#  ('how-to', 374845675.0, 7627111.0),
#  ('business', 347342749.0, 3455171.0),
#  ('tutorial', 338051602.0, 8386044.0),
#  ('finance', 27074714.0, 516184.0),
#  ('crypto', 20230411.0, 426068.0),
#  ('cubes', 722031860.0, 14813301.0),
#  ('chess', 62101455.0, 1692700.0),
#  ('apple', 451371072.0, 4959314.0),
#  ('google', 4528429199.0, 20852614.0),
#  ('interview', 147684500.0, 3646717.0),
#  ('history', 750809472.0, 13656232.0),
#  ('literature', 39698977.0, 819969.0),
#  ('bed', 2371302040.0, 20842016.0),
#  ('trolling', 71007051.0, 3069352.0),
#  ('asmr', 60728506.0, 1341640.0),
#  ('music', 1346863960.0, 14358522.0),
#  ('food', 252115499.0, 4560703.0),
#  ('mukbang', 472712036.0, 5984442.0),
#  ('reaction', 6098678.0, 499826.0),
# ...

# %%
# %sql select * from Comment_data limit 50;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 50 rows affected.
# [('wAZZ-UWGVHI', "Let's not forget that Apple Pay in 2014 required a brand new iPhone in order to use it.  A significant portion of Apple's user base wasn't able to us ... (27 characters truncated) ... .  As each successive iPhone incorporated the technology and older iPhones were replaced the number of people who could use the technology increased.", 95, 1),
#  ('wAZZ-UWGVHI', 'Here in NZ 50% of retailers don’t even have contactless credit card machines like pay-wave which support Apple Pay. They don’t like the high fees that come with these.', 19, 0),
#  ('wAZZ-UWGVHI', "I will forever acknowledge this channel with the help of your lessons and ideas explanations, Now It's quite helpful while you'll just sit at your comfort and monitor your account Growth.", 161, 2),
# ...

# %% [markdown]
# ## Lets join the two tables into one and perform more analysis using the newly joined table

# %%
# %%sql
# create table joined as
# select videos_stats.Title,videos_stats.Video_Id,videos_stats.Published_at,videos_stats.Keyword,videos_stats.Likes,videos_stats.Comments as total_comments,videos_stats.Views,Comment_data.Comment,Comment_data.Likes as commentslike,Comment_data.Sentiment
# from videos_stats
# left join Comment_data
# On videos_stats.Video_Id=Comment_data.Video_id;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 18160 rows affected.
# []

# %%
# %sql select * from joined limit 20
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 20 rows affected.
# [('Apple Pay Is Killing the Physical Wallet After Only Eight Years | Tech News Briefing Podcast | WSJ', 'wAZZ-UWGVHI', datetime.date(2022, 8, 23), 'tech', 3407.0, 672.0, 135612.0, 'In Cambodia, we have a universal QR code system, we scan and send money back and forth, all banks take no profit from merchant, they receive 100% of the payment. A lot of stores and supermarkets start abandon POS machine all together.', 28, 1),
#  ('Apple Pay Is Killing the Physical Wallet After Only Eight Years | Tech News Briefing Podcast | WSJ', 'wAZZ-UWGVHI', datetime.date(2022, 8, 23), 'tech', 3407.0, 672.0, 135612.0, "In the United States, we have an abundance of retailers that accept Apple Pay, but it's still good to carry the physical card with you, being there are still a large quantity of places that do NOT accept Apple Pay.", 2, 2),
# ...

# %% [markdown]
# ### What are the top 10 most-liked comments?

# %%
# %sql select Video_Id,Comment,commentslike from joined order by commentslike  desc limit 10;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 10 rows affected.
# [('0e3GPea1Tyg', 'Like I said in the video, subscribe if you haven’t already and you could win $10,000!', 891372),
#  ('0e3GPea1Tyg', 'Huge props to the set designers, everything was spot on!', 469175),
#  ('9bqk6ZUsKyA', 'Like I said in the video, subscribe if you haven’t already and you could win $10,000!', 268266),
#  ('YyhKdOCwD7s', "Subscribe and i'll give you a car", 260871),
#  ('QxGVgXf_LNk', 'Subscribe or I’ll drop kick you\n-me 2019', 232310),
#  ('erQ_9yEz0ls', 'Subscribe or you’ll have bad luck', 218435),
#  ('dg2Ag3e8W-Q', 'Mrbeast doesnt go to the bank to get money. The bank goes to Mrbeast to withdraw money..', 195704),
#  ('9bqk6ZUsKyA', 'imagine just randomly digging in that area and finding mrbeast lying in there with bottles of piss', 181924),
#  ('lTRiuFIWV54', 'I am here to proudly announce that it is 3am and I have finished all of my homework', 180576),
# ...

# %% [markdown]
# ### What is the average sentiment score in each keyword category?

# %%
# %%sql
# select keyword,avg(Sentiment) as averagesentimentscore from joined group by keyword;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 41 rows affected.
# [('tech', Decimal('1.5068')),
#  ('news', Decimal('0.8140')),
#  ('gaming', Decimal('1.4731')),
#  ('sports', Decimal('1.4923')),
#  ('google', Decimal('1.3380')),
#  ('literature', Decimal('1.5941')),
#  ('asmr', Decimal('1.7436')),
#  ('animals', Decimal('1.5140')),
#  ('biology', Decimal('1.5085')),
#  ('physics', Decimal('1.5540')),
#  ('computer science', Decimal('1.6049')),
#  ('nintendo', Decimal('1.5565')),
#  ('movies', Decimal('1.4828')),
#  ('machine learning', Decimal('1.7426')),
#  ('finance', Decimal('1.2138')),
#  ('crypto', Decimal('1.4254')),
#  ('history', Decimal('1.1702')),
#  ('bed', Decimal('1.6697')),
#  ('music', Decimal('1.7438')),
#  ('food', Decimal('1.6499')),
#  ('reaction', Decimal('1.5386')),
#  ('chess', Decimal('1.4358')),
#  ('interview', Decimal('1.6230')),
#  ('trolling', Decimal('1.2060')),
#  ('mukbang', Decimal('1.6419')),
#  ('marvel', Decimal('1.4826')),
# ...

# %% [markdown]
# ### How many times do company names (i.e., apple or google) appear in each keyword category?

# %%
# %%sql
# select keyword,count(keyword) as No_of_company_apperances  from joined  where keyword='apple'or keyword='google' group by keyword;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 2 rows affected.
# [('google', 432), ('apple', 415)]

# %% [markdown]
# ### How many total videoes does each category have?

# %%
# %%sql
# select keyword,count(Video_Id) as total_videos_per_eachcategory from joined group by keyword;
# Out:
#  * mysql+mysqldb://root:***@localhost/youtubeanalysis
# 41 rows affected.
# [('tech', 730),
#  ('news', 344),
#  ('gaming', 372),
#  ('sports', 453),
#  ('google', 432),
#  ('literature', 441),
#  ('asmr', 468),
#  ('animals', 358),
#  ('biology', 470),
#  ('physics', 500),
#  ('computer science', 453),
#  ('nintendo', 469),
#  ('movies', 406),
#  ('machine learning', 470),
#  ('finance', 318),
#  ('crypto', 456),
#  ('history', 470),
#  ('bed', 433),
#  ('music', 406),
#  ('food', 477),
#  ('reaction', 479),
#  ('chess', 436),
#  ('interview', 488),
#  ('trolling', 500),
#  ('mukbang', 430),
#  ('marvel', 489),
#  ('game development', 490),
#  ('minecraft', 443),
#  ('xbox', 474),
#  ('how-to', 477),
#  ('apple', 415),
#  ('lofi', 363),
#  ('mrbeast', 468),
#  ('data science', 482),
#  ('tutorial', 500),
#  ('cubes', 487),
#  ('sat', 489),
#  ('cnn', 497),
#  ('business', 456),
#  ('education', 238),
#  ('mathchemistry', 133)]
